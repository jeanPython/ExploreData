# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header=1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
print(credit)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
credit.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
credit.isnull().values.any()
# Out:
# False

# %%
from sklearn.preprocessing import KBinsDiscretizer
from feature_engine.discretisers import EqualFrequencyDiscretiser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-8c7c73d0d567> in <module>
#       1 from sklearn.preprocessing import KBinsDiscretizer
# ----> 2 from feature_engine.discretisers import EqualFrequencyDiscretiser
#
# ModuleNotFoundError: No module named 'feature_engine'

# %%
credit.plot()

# %%
credit.corr()
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
import seaborn as sn

# %%
corrMatrix = credit.corr()

# %%
sn.heatmap(corrMatrix, annot=True)

# %%
import numpy as np

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
x = credit.iloc[:,0:24]
y = credit.iloc[:,24]
bestfeatures = SelectKBest(score_func=chi2, k=10)

# %%
for index in credit.index:
    if credit['PAY_2'][index] == -2:
        credit['PAY_2'][index] = 200
    elif credit['PAY_2'][index] == -1:
        credit['PAY_2'][index] == 100

for index in credit.index:
    if credit['PAY_0'][index] == -2:
        credit['PAY_0'][index] = 200
    elif credit['PAY_0'][index] == -1:
        credit['PAY_0'][index] == 100

for index in credit.index:
    if credit['PAY_3'][index] == -2:
        credit['PAY_3'][index] = 200
    elif credit['PAY_3'][index] == -1:
        credit['PAY_3'][index] == 100

for index in credit.index:
    if credit['PAY_4'][index] == -2:
        credit['PAY_4'][index] = 200
    elif credit['PAY_4'][index] == -1:
        credit['PAY_4'][index] == 100
        
for index in credit.index:
    if credit['PAY_5'][index] == -2:
        credit['PAY_5'][index] = 200
    elif credit['PAY_5'][index] == -1:
        credit['PAY_5'][index] == 100
        
for index in credit.index:
    if credit['PAY_6'][index] == -2:
        credit['PAY_6'][index] = 200
    elif credit['PAY_6'][index] == -1:
        credit['PAY_6'][index] == 100

# %%
credit.iloc[:,7:12].describe()
# Out:
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      45.700033     47.330733     48.202100     48.991500     51.993233
# std       70.510646     72.018692     73.282896     74.217568     75.746010
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%      100.000000    100.000000    100.000000    100.000000    100.000000
# max      200.000000    200.000000    200.000000    200.000000    200.000000

# %%
credit.iloc[:,13:24].describe()
# Out:
#            BILL_AMT2     BILL_AMT3      BILL_AMT4      BILL_AMT5  \
# count   30000.000000  3.000000e+04   30000.000000   30000.000000
# mean    49179.075167  4.701315e+04   43262.948967   40311.400967
# std     71173.768783  6.934939e+04   64332.856134   60797.155770
# min    -69777.000000 -1.572640e+05 -170000.000000  -81334.000000
# 25%      2984.750000  2.666250e+03    2326.750000    1763.000000
# 50%     21200.000000  2.008850e+04   19052.000000   18104.500000
# 75%     64006.250000  6.016475e+04   54506.000000   50190.500000
# max    983931.000000  1.664089e+06  891586.000000  927171.000000
#
#            BILL_AMT6       PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# count   30000.000000   30000.000000  3.000000e+04   30000.00000
# mean    38871.760400    5663.580500  5.921163e+03    5225.68150
# std     59554.107537   16563.280354  2.304087e+04   17606.96147
# min   -339603.000000       0.000000  0.000000e+00       0.00000
# ...

# %%
for index in credit.index:
    if credit['BILL_AMT1'][index] < 0:
        credit['BILL_AMT1'][index] = 0
        
for index in credit.index:
    if credit['BILL_AMT3'][index] < 0:
        credit['BILL_AMT3'][index] = 0

for index in credit.index:
    if credit['BILL_AMT4'][index] < 0:
        credit['BILL_AMT4'][index] = 0
        
for index in credit.index:
    if credit['BILL_AMT5'][index] < 0:
        credit['BILL_AMT5'][index] = 0
        
for index in credit.index:
    if credit['BILL_AMT6'][index] < 0:
        credit['BILL_AMT6'][index] = 0
        
for index in credit.index:
    if credit['BILL_AMT2'][index] < 0:
        credit['BILL_AMT2'][index] = 0

# %%
credit.iloc[:,13:24].describe()
# Out:
#            BILL_AMT2     BILL_AMT3      BILL_AMT4      BILL_AMT5  \
# count   30000.000000  3.000000e+04   30000.000000   30000.000000
# mean    49206.518033  4.704517e+04   43299.651933   40347.092100
# std     71150.744613  6.931878e+04   64294.968472   60766.619726
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      2984.750000  2.666250e+03    2326.750000    1763.000000
# 50%     21200.000000  2.008850e+04   19052.000000   18104.500000
# 75%     64006.250000  6.016475e+04   54506.000000   50190.500000
# max    983931.000000  1.664089e+06  891586.000000  927171.000000
#
#            BILL_AMT6       PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# count   30000.000000   30000.000000  3.000000e+04   30000.00000
# mean    38942.268767    5663.580500  5.921163e+03    5225.68150
# std     59445.970807   16563.280354  2.304087e+04   17606.96147
# min         0.000000       0.000000  0.000000e+00       0.00000
# ...

# %%
fit = bestfeatures.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-0a1a3e393f5e> in <module>
# ----> 1 fit = bestfeatures.fit(X,y)
#
# NameError: name 'X' is not defined

# %%
fit = bestfeatures.fit(x,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']

print(featureScores.nlargest(10,'Score'))
# Out:
#         Specs         Score
# 1   LIMIT_BAL  7.106584e+07
# 19   PAY_AMT2  9.229476e+06
# 18   PAY_AMT1  7.728847e+06
# 20   PAY_AMT3  5.630969e+06
# 23   PAY_AMT6  5.141638e+06
# 21   PAY_AMT4  4.926667e+06
# 22   PAY_AMT5  4.433484e+06
# 12  BILL_AMT1  1.239053e+06
# 13  BILL_AMT2  6.295760e+05
# 14  BILL_AMT3  6.039238e+05

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06119672 0.06303373 0.01219011 0.03233203 0.02168173 0.05897477
#  0.08109677 0.04846834 0.03410876 0.0281024  0.02901356 0.02613225
#  0.04685361 0.04368717 0.04224192 0.04103795 0.03984796 0.04106336
#  0.04366175 0.04145979 0.03985728 0.03917924 0.04095521 0.04382359]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
import seaborn as sns

# %%
corrmat = credit.corr()

# %%
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(credit[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
import seaborn as sns

# %%
sns.catplot(x="default payment next month", kind="count", data=credit);

# %%
sns.catplot(x="default payment next month", y="LIMIT_BAL", hue="PAY_0", kind="point", 
            data=credit);

# %%
sns.catplot(x="default payment next month", y="LIMIT_BAL", hue="PAY_2", kind="point", 
            data=credit);

# %%
sns.catplot(x="default payment next month", y="EDUCATION",hue="PAY_2", kind="point", 
            data=credit);

# %%
sns.catplot(x="default payment next month", y="EDUCATION",hue="AGE", kind="point", 
            data=credit);

# %%
sns.catplot(x="default payment next month", y="AGE",hue="EDUCATION", kind="point", 
            data=credit);
